# %% [markdown]
# # Scouting Young Forward Player for Manchester United
#
# ## What/Why is Manchester United?
# Before begin, my favorite habit is watching football, and I've been a passionate Manchester United fan since I was 14 years old. For me, watching football goes beyond being just a normal sport; it encompasses passion, history, emotions, business dynamics, and even tactical intricacies.
#
# Manchester United is an English club and one of the most popular in the world. Currently, they are led by Erik ten Hag, who is manager has set-up the Possession-based and Total Football style to Manchester United.

# %% [markdown]
# # This Project
# ## Issue last season 2022-23
# ![Screen Shot 2566-08-11 at 16.23.13.png](attachment:99469ad1-0703-4e50-a7c6-ad286f2ab3a9.png)
#
# ### Manchester United has a chance to score but without goal
# Manchester United has the highest shot on target 5.4/90 miniute compared to other big 3 clubs like Liverpool, Arsenal, and Manchester City.
# However, they have scored fewer goals than these teams. This is big issue last seanson and raises questions about how Manchester United can improve in goal conversion. (<a href="https://jupyter.org/try-jupyter/lab?path=ScountingYoungPlayer%2FClubAnalysis.ipynb">source</a>)
